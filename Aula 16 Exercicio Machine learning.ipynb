# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# Mapeamento do caminho e arquivo
path = 'C:\\Users\\FIC\\Documents\\david_python\\'
file = 'protetor_solar.csv'

# Atribuir o arquivo a um dataframe
protetorSolar = pd.read_csv(path + file)

protetorSolar
# Out:
#     temperatura        qtde
# 0     24.349104  572.672047
# 1     26.168859  658.600456
# 2      5.307507  242.509855
# 3     17.997015  441.002944
# 4     30.965087  702.623614
# ..          ...         ...
# 89    14.931506  377.430928
# 90    25.112066  571.434257
# 91    22.274899  524.746364
# 92    32.893092  755.818399
# 93    12.588157  306.090719
#
# [94 rows x 2 columns]

# %%
protetorSolar.columns = ['Temperatura', 'Vendas']

# %%
sns.jointplot(x = 'Temperatura', y= 'Vendas', data = protetorSolar, color = 'red')

# %%
sns.pairplot(protetorSolar)
# Out:
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.lmplot(
    x = 'Temperatura',
    y = 'Vendas',
    data = protetorSolar
           )
# Out:
# c:\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
x = protetorSolar[['Temperatura']]
y = protetorSolar['Vendas']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(x,y, test_size=0.25)

# %%
from sklearn.linear_model import LinearRegression

# %%
regressor = LinearRegression(fit_intercept= True)
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('Coeficiente angular (a): ', regressor.coef_)
print('Coficiente linear (b):', regressor.intercept_)
# Out:
# Coeficiente angular (a):  [21.51734513]
# Coficiente linear (b): 46.30406665479944

# %%
y_previsao = regressor.predict(X_test)

y_previsao
# Out:
# array([498.73633223, 477.00351758, 454.11199496, 681.24207332,
#        433.5520456 , 845.18005276, 608.38311795, 512.79789339,
#        511.30774688, 528.24907396, 573.15429586, 549.96609338,
#        525.60076173, 638.93394592, 666.64394274, 453.16454279,
#        633.32013255, 878.3411249 , 151.00474873, 452.70564237,
#        445.48609711, 295.79989325, 913.53414859, 696.73260481])

# %%
# Criar um gráfico de dispersão

plt.scatter(X_train,y_train, color = 'green')
plt.plot(X_train, regressor.predict(X_train), color = 'red')
plt.ylabel('Receita [Dolares]')
plt.xlabel('Temperatura [°C]')
plt.title('Receita gerada Vs. Temperatura (Vendas de Protetor Solar)')
# Out:
# Text(0.5, 1.0, 'Receita gerada Vs. Temperatura (Vendas de Protetor Solar)')
